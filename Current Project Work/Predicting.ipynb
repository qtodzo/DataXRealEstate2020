# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pmdarima

# %%
# !pip install pmdarima
# Out:
# Collecting pmdarima
#   Using cached https://files.pythonhosted.org/packages/83/aa/feb76414043592c3149059ab772a51de03fbf7544a8e19237f229a50a949/pmdarima-1.5.3-cp36-cp36m-manylinux1_x86_64.whl
# Requirement already satisfied: pandas>=0.19 in /srv/app/venv/lib/python3.6/site-packages (from pmdarima)
# Collecting scipy>=1.3.2 (from pmdarima)
#   Using cached https://files.pythonhosted.org/packages/dc/29/162476fd44203116e7980cfbd9352eef9db37c49445d1fec35509022f6aa/scipy-1.4.1-cp36-cp36m-manylinux1_x86_64.whl
# Collecting numpy>=1.17.3 (from pmdarima)
#   Using cached https://files.pythonhosted.org/packages/3d/fc/4763e5f17ac6e7e7d55f377cde859ca1c5d5ac624441ab45315bc578aa9e/numpy-1.18.3-cp36-cp36m-manylinux1_x86_64.whl
# Requirement already satisfied: urllib3 in /srv/app/venv/lib/python3.6/site-packages (from pmdarima)
# Requirement already satisfied: Cython>=0.29 in /srv/app/venv/lib/python3.6/site-packages (from pmdarima)
# Collecting statsmodels>=0.10.2 (from pmdarima)
#   Using cached https://files.pythonhosted.org/packages/cb/83/540fd83238a18abe6c2d280fa8e489ac5fcefa1f370f0ca1acd16ae1b860/statsmodels-0.11.1-cp36-cp36m-manylinux1_x86_64.whl
# Requirement already satisfied: joblib>=0.11 in /srv/app/venv/lib/python3.6/site-packages (from pmdarima)
# Collecting scikit-learn>=0.22 (from pmdarima)
#   Using cached https://files.pythonhosted.org/packages/5e/d8/312e03adf4c78663e17d802fe2440072376fee46cada1404f1727ed77a32/scikit_learn-0.22.2.post1-cp36-cp36m-manylinux1_x86_64.whl
# Requirement already satisfied: pytz>=2011k in /srv/app/venv/lib/python3.6/site-packages (from pandas>=0.19->pmdarima)
# Requirement already satisfied: python-dateutil>=2.5.0 in /srv/app/venv/lib/python3.6/site-packages (from pandas>=0.19->pmdarima)
# Requirement already satisfied: patsy>=0.5 in /srv/app/venv/lib/python3.6/site-packages (from statsmodels>=0.10.2->pmdarima)
# Requirement already satisfied: six>=1.5 in /srv/app/venv/lib/python3.6/site-packages (from python-dateutil>=2.5.0->pandas>=0.19->pmdarima)
# Installing collected packages: numpy, scipy, statsmodels, scikit-learn, pmdarima
#   Found existing installation: numpy 1.16.0
#     Uninstalling numpy-1.16.0:
#       Successfully uninstalled numpy-1.16.0
#   Found existing installation: scipy 1.2.0
#     Uninstalling scipy-1.2.0:
#       Successfully uninstalled scipy-1.2.0
#   Found existing installation: statsmodels 0.8.0
#     Uninstalling statsmodels-0.8.0:
#       Successfully uninstalled statsmodels-0.8.0
#   Found existing installation: scikit-learn 0.21.3
#     Uninstalling scikit-learn-0.21.3:
#       Successfully uninstalled scikit-learn-0.21.3
# Successfully installed numpy-1.18.3 pmdarima-1.5.3 scikit-learn-0.22.2.post1 scipy-1.4.1 statsmodels-0.11.1
# You are using pip version 9.0.3, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
pip install --upgrade pip
# Out:
# Cache entry deserialization failed, entry ignored
# Collecting pip
#   Using cached https://files.pythonhosted.org/packages/54/0c/d01aa759fdc501a58f431eb594a17495f15b88da142ce14b5845662c13f3/pip-20.0.2-py2.py3-none-any.whl
# Installing collected packages: pip
#   Found existing installation: pip 9.0.3
#     Uninstalling pip-9.0.3:
#       Successfully uninstalled pip-9.0.3
# Successfully installed pip-20.0.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Redfin Data #

# %%
#sf_median_prices = pd.read_csv("SF_Refin_RealEstate_Full.csv")

# %%
sf_median_prices
# Out:
#                City    last_updated  Measure Display parent_metro_region  \
# 0     San Francisco  4/5/2020 14:45              NaN   San Francisco, CA
#
# 8217      San Francisco, CA - Western South of Market  Neighborhood
# 8218              San Francisco, CA - Lakeshore Acres  Neighborhood
# 8219  San Francisco, CA - Ashbury Heights / Parnassus  Neighborhood
# 8220                San Francisco, CA - Lone Mountain  Neighborhood
# 8221               San Francisco, CA - Telegraph Hill  Neighborhood
# 8222                San Francisco, CA - Balboa Hollow  Neighborhood
# 8223                    San Francisco, CA - Sunnyside  Neighborhood
# 8224                  San Francisco, CA - Lake Street  Neighborhood
# 8225                San Francisco, CA - Balboa Hollow  Neighborhood
# 8226      San Francisco, CA - Western South of Market  Neighborhood
# 8227      San Francisco, CA - Southwest San Francisco  Neighborhood
# 8228            San Francisco, CA - Clarendon Heights  Neighborhood
# 8229              San Francisco, CA - Peralta Heights  Neighborhood
# 8230                  San Francisco, CA - North Beach  Neighborhood
#
#       Seasonally Adjusted         ...         pending_sales_yoy  \
# 0                   False         ...                  0.123596
# 1                   False         ...                 -0.275862
# 2                   False         ...                  0.000000
# 3                   False         ...                  3.000000
# 4                   False         ...                  1.000000
# 5                   False         ...                 -0.125000
# 6                   False         ...                  0.142857
# 7                   False         ...                 -0.461538
# 8                   False         ...                  8.000000
# 9                   False         ...                  0.666667
# 10                  False         ...                 -0.166667
# 11                  False         ...                 -0.125000
# 12                  False         ...                 -0.600000
# 13                  False         ...                 -0.111111
# 14                  False         ...                  0.000000
# 15                  False         ...                 -0.107143
# 16                  False         ...                       NaN
# 17                  False         ...                 -0.333333
# 18                  False         ...                       NaN
# 19                  False         ...                 -0.082126
# 20                  False         ...                 -0.615385
# 21                  False         ...                  0.200000
# 22                  False         ...                  0.333333
# 23                  False         ...                 -0.142857
# 24                  False         ...                  2.750000
# 25                  False         ...                 -0.230769
# 26                  False         ...                 -0.250000
# 27                  False         ...                 -0.500000
# 28                  False         ...                 -0.222222
# 29                  False         ...                  0.000000
# ...                   ...         ...                       ...
# 8201                False         ...                  0.312500
# 8202                False         ...                 -0.500000
# 8203                False         ...                  1.666667
# 8204                False         ...                  4.000000
# 8205                False         ...                  0.050000
# 8206                False         ...                  1.000000
# 8207                False         ...                  0.333333
# 8208                False         ...                 -0.666667
# 8209                False         ...                 -0.375000
# 8210                False         ...                 -0.381818
# 8211                False         ...                 -0.600000
# 8212                False         ...                  0.428571
# 8213                False         ...                       NaN
# 8214                False         ...                 -0.500000
# 8215                False         ...                 -0.354839
# 8216                False         ...                       NaN
# 8217                False         ...                  0.166667
# 8218                False         ...                 -0.857143
# 8219                False         ...                  0.111111
# 8220                False         ...                  1.000000
# 8221                False         ...                 -0.750000
# 8222                False         ...                 -0.800000
# 8223                False         ...                 -0.857143
# 8224                False         ...                  2.000000
# 8225                False         ...                  5.000000
# 8226                False         ...                 -0.071429
# 8227                False         ...                  0.016260
# 8228                False         ...                  2.000000
# 8229                False         ...                  0.000000
# 8230                False         ...                  0.666667
#
#      Period Duration  Price Drops Price Drops Mom  Price Drops Yoy  \
# 0                 90          NaN             NaN              NaN
# 1                 90          NaN             NaN              NaN
# 2                 90          NaN             NaN              NaN
# 3                 90          NaN             NaN              NaN
# 4                 90          NaN             NaN              NaN
# 5                 90          NaN             NaN              NaN
# 6                 90          NaN             NaN              NaN
# 7                 90          NaN             NaN              NaN
# 8                 90          NaN             NaN              NaN
# 9                 90          NaN             NaN              NaN
# 10                90          NaN             NaN              NaN
# 11                90          NaN             NaN              NaN
# 12                90          NaN             NaN              NaN
# 13                90          NaN             NaN              NaN
# 14                90          NaN             NaN              NaN
# 15                90          NaN             NaN              NaN
# 16                90          NaN             NaN              NaN
# 17                90          NaN             NaN              NaN
# 18                90          NaN             NaN              NaN
# 19                90          NaN             NaN              NaN
# 20                90          NaN             NaN              NaN
# 21                90          NaN             NaN              NaN
# 22                90          NaN             NaN              NaN
# 23                90          NaN             NaN              NaN
# 24                90          NaN             NaN              NaN
# 25                90          NaN             NaN              NaN
# 26                90          NaN             NaN              NaN
# 27                90          NaN             NaN              NaN
# 28                90          NaN             NaN              NaN
# 29                90          NaN             NaN              NaN
# ...              ...          ...             ...              ...
# 8201              90          NaN             NaN              NaN
# 8202              90          NaN             NaN              NaN
# 8203              90          NaN             NaN              NaN
# 8204              90          NaN             NaN              NaN
# 8205              90          NaN             NaN              NaN
# 8206              90          NaN             NaN              NaN
# 8207              90          NaN             NaN              NaN
# 8208              90          NaN             NaN              NaN
# 8209              90          NaN             NaN              NaN
# 8210              90          NaN             NaN              NaN
# 8211              90          NaN             NaN              NaN
# 8212              90          NaN             NaN              NaN
# 8213              90          NaN             NaN              NaN
# 8214              90          NaN             NaN              NaN
# 8215              90          NaN             NaN              NaN
# 8216              90          NaN             NaN              NaN
# 8217              90          NaN             NaN              NaN
# 8218              90          NaN             NaN              NaN
# 8219              90          NaN             NaN              NaN
# 8220              90          NaN             NaN              NaN
# 8221              90          NaN             NaN              NaN
# 8222              90          NaN             NaN              NaN
# 8223              90          NaN             NaN              NaN
# 8224              90          NaN             NaN              NaN
# 8225              90          NaN             NaN              NaN
# 8226              90          NaN             NaN              NaN
# 8227              90          NaN             NaN              NaN
# 8228              90          NaN             NaN              NaN
# 8229              90          NaN             NaN              NaN
# 8230              90          NaN             NaN              NaN
#
#       property_type_id  region_type_id  Sold Above List Sold Above List Mom  \
# 0                   -1               1         0.414286            0.050000
# 1                   -1               1         0.418182            0.097427
# 2                   -1               1         0.428571           -0.045113
# 3                   -1               1         0.666667           -0.133333
# 4                   -1               1         0.472222           -0.037982
# 5                   -1               1         0.625000           -0.041667
# 6                   -1               1         0.642857            0.087302
# 7                   -1               1         0.533333            0.055072
# 8                   -1               1         0.606061            0.034632
# 9                   -1               1         0.611111           -0.111111
# 10                  -1               1         0.846154            0.022624
# 11                  -1               1         0.652174           -0.014493
# 12                  -1               1         0.625000           -0.125000
# 13                  -1               1         0.590278           -0.032239
# 14                  -1               1         0.764706            0.072398
# 15                  -1               1         0.511628           -0.056333
# 16                  -1               1         1.000000            0.142857
# 17                  -1               1         0.800000           -0.200000
# 18                  -1               1         0.666667           -0.133333
# 19                  -1               1         0.813142            0.051122
# 20                  -1               1         0.818182           -0.181818
# 21                  -1               1         0.923077            0.099548
# 22                  -1               1         0.944444            0.069444
# 23                  -1               1         0.636364           -0.149351
# 24                  -1               1         0.516129            0.096774
# 25                  -1               1         0.708333            0.075000
# 26                  -1               1         0.818182           -0.090909
# 27                  -1               1         0.555556            0.222222
# 28                  -1               1         0.615385            0.009324
# 29                  -1               1         0.750000            0.000000
# ...                ...             ...              ...                 ...
# 8201                -1               1         0.773585           -0.057584
# 8202                -1               1         0.714286            0.000000
# 8203                -1               1         0.857143           -0.142857
# 8204                -1               1         0.666667           -0.333333
# 8205                -1               1         0.396552           -0.081709
# 8206                -1               1         0.714286           -0.026455
# 8207                -1               1         0.285714            0.142857
# 8208                -1               1         1.000000            0.166667
# 8209                -1               1         0.750000            0.000000
# 8210                -1               1         0.387324            0.000657
# 8211                -1               1         0.700000            0.088889
# 8212                -1               1         0.684211            0.037152
# 8213                -1               1         0.833333           -0.083333
# 8214                -1               1         0.852459           -0.033255
# 8215                -1               1         0.518797           -0.079968
# 8216                -1               1         1.000000            0.166667
# 8217                -1               1         0.705882            0.086835
# 8218                -1               1         1.000000            0.000000
# 8219                -1               1         0.941176            0.107843
# 8220                -1               1         0.750000            0.250000
# 8221                -1               1         0.250000            0.083333
# 8222                -1               1         1.000000            0.250000
# 8223                -1               1         0.700000           -0.033333
# 8224                -1               1         0.500000            0.100000
# 8225                -1               1         0.769231           -0.064103
# 8226                -1               1         0.655172            0.083744
# 8227                -1               1         0.764706           -0.031014
# 8228                -1               1         0.600000           -0.127273
# 8229                -1               1         0.600000           -0.169231
# 8230                -1               1         0.666667           -0.047619
#
#      Sold Above List Yoy
# 0               0.039568
# 1               0.006417
# 2               0.011905
# 3               0.128205
# 4               0.157937
# 5               0.275000
# 6               0.202857
# 7               0.220833
# 8               0.320346
# 9               0.166667
# 10              0.179487
# 11              0.116460
# 12              0.163462
# 13              0.166278
# 14              0.098039
# 15              0.080689
# 16              0.750000
# 17             -0.200000
# 18             -0.133333
# 19              0.053230
# 20              0.112299
# 21              0.110577
# 22              0.044444
# 23              0.025253
# 24              0.016129
# 25             -0.005952
# 26              0.193182
# 27             -0.262626
# 28              0.063660
# 29              0.083333
# ...                  ...
# 8201            0.009949
# 8202           -0.285714
# 8203           -0.101190
# 8204           -0.333333
# 8205            0.040620
# 8206           -0.230159
# 8207           -0.014286
# 8208            0.222222
# 8209            0.027778
# 8210           -0.094158
# 8211           -0.050000
# 8212           -0.186757
# 8213           -0.023810
# 8214            0.016843
# 8215            0.055834
# 8216            0.166667
# 8217            0.154158
# 8218            0.250000
# 8219            0.041176
# 8220            0.386364
# 8221            0.107143
# 8222            0.454545
# 8223           -0.069231
# 8224           -0.357143
# 8225           -0.016484
# 8226            0.222740
# 8227            0.005447
# 8228           -0.066667
# 8229            0.100000
# 8230           -0.333333
#
# [8231 rows x 64 columns]

# %%
sf_median_prices.columns
# Out:
# Index(['City', 'last_updated', 'Measure Display', 'parent_metro_region',
#        'Period Begin', 'Period End', 'Property Type', 'Region', 'Region Type',
#        'Seasonally Adjusted', 'State', 'State Code', 'Table Id',
#        'Worksheet Filter', 'active_listings', 'active_listings_mom',
#        'active_listings_yoy', 'Avg Sale To List', 'Avg Sale To List Mom',
#        'Avg Sale To List Yoy', 'Homes Sold', 'Homes Sold Mom',
#        'Homes Sold Yoy', 'Inventory', 'Inventory Mom', 'Inventory Yoy',
#        'Median Dom', 'Median Dom Mom', 'Median Dom Yoy', 'Median List Ppsf',
#        'Median List Ppsf Mom', 'Median List Ppsf Yoy', 'Median List Price',
#        'Median List Price Mom', 'Median List Price Yoy', 'Median Ppsf',
#        'Median Ppsf Mom', 'Median Ppsf Yoy', 'Median Sale Price',
#        'Median Sale Price Mom', 'Median Sale Price Yoy', 'months_of_supply',
#        'months_of_supply_mom', 'months_of_supply_yoy', 'New Listings',
#        'New Listings Mom', 'New Listings Yoy', 'Number of Records',
#        'off_market_in_two_weeks', 'off_market_in_two_weeks_mom',
#        'off_market_in_two_weeks_yoy', 'parent_metro_region_metro_code',
#        'pending_sales', 'pending_sales_mom', 'pending_sales_yoy',
#        'Period Duration', 'Price Drops', 'Price Drops Mom', 'Price Drops Yoy',
#        'property_type_id', 'region_type_id', 'Sold Above List',
#        'Sold Above List Mom', 'Sold Above List Yoy'],
#       dtype='object')

# %% [markdown]
# # Zillow Data #

# %%
zillow = pd.read_csv("Neighborhood_Zhvi_AllHomes.csv")

# %%
zillow[zillow['City'] == 'San Francisco'].head()
# Out:
#      RegionID  SizeRank      RegionName    RegionType StateName State  \
# 178    268384       182    Outer Sunset  Neighborhood        CA    CA
# 256    274552       262         Mission  Neighborhood        CA    CA
# 386    268383       401  Outer Richmond  Neighborhood        CA    CA
# 460    268219       481  Inner Richmond  Neighborhood        CA    CA
# 514    268396       537        Parkside  Neighborhood        CA    CA
#
#               City                          Metro            CountyName  \
# 178  San Francisco  San Francisco-Oakland-Hayward  San Francisco County
# 256  San Francisco  San Francisco-Oakland-Hayward  San Francisco County
# 386  San Francisco  San Francisco-Oakland-Hayward  San Francisco County
# 460  San Francisco  San Francisco-Oakland-Hayward  San Francisco County
# 514  San Francisco  San Francisco-Oakland-Hayward  San Francisco County
#
#      1996-01-31     ...      2019-06-30  2019-07-31  2019-08-31  2019-09-30  \
# 178    281542.0     ...       1352307.0   1355850.0   1356184.0   1365300.0
# 256    248722.0     ...       1487391.0   1483819.0   1471945.0   1469175.0
# 386    364886.0     ...       1569494.0   1575815.0   1576816.0   1588677.0
# 460    416245.0     ...       2128617.0   2124000.0   2110026.0   2101137.0
# 514    299441.0     ...       1394726.0   1399913.0   1402299.0   1409094.0
#
#      2019-10-31  2019-11-30  2019-12-31  2020-01-31  2020-02-29  2020-03-31
# 178   1374803.0   1386311.0   1403026.0   1411558.0   1420794.0   1426495.0
# 256   1475606.0   1486465.0   1497416.0   1502307.0   1506689.0   1506592.0
# 386   1595248.0   1605978.0   1619411.0   1628408.0   1635501.0   1638102.0
# 460   2101688.0   2101768.0   2115011.0   2126079.0   2140365.0   2139254.0
# 514   1416884.0   1426611.0   1441516.0   1450781.0   1460379.0   1462524.0
#
# [5 rows x 300 columns]

# %%
sf_zillow = zillow[zillow['City'] == 'San Francisco'].drop(['RegionID', 'State', 'Metro', 'CountyName', 'City', 'SizeRank'], axis=1).set_index('RegionName')

# %%
sf_zillow.head()
# Out:
#                   RegionType StateName  1996-01-31  1996-02-29  1996-03-31  \
# RegionName
# Outer Sunset    Neighborhood        CA    281542.0    280692.0    280344.0
# Mission         Neighborhood        CA    248722.0    247234.0    246912.0
# Outer Richmond  Neighborhood        CA    364886.0    363632.0    363033.0
# Inner Richmond  Neighborhood        CA    416245.0    415703.0    415728.0
# Parkside        Neighborhood        CA    299441.0    298286.0    297377.0
#
#                 1996-04-30  1996-05-31  1996-06-30  1996-07-31  1996-08-31  \
# RegionName
# Outer Sunset      279465.0    278701.0    277975.0    277295.0    277477.0
# Mission           246186.0    245295.0    243570.0    241785.0    242816.0
# Outer Richmond    361349.0    360376.0    359990.0    360356.0    361147.0
# Inner Richmond    416848.0    417485.0    417173.0    415724.0    416227.0
# Parkside          295732.0    294378.0    293709.0    293359.0    294045.0
#
#                    ...      2019-06-30  2019-07-31  2019-08-31  2019-09-30  \
# RegionName         ...
# Outer Sunset       ...       1352307.0   1355850.0   1356184.0   1365300.0
# Mission            ...       1487391.0   1483819.0   1471945.0   1469175.0
# Outer Richmond     ...       1569494.0   1575815.0   1576816.0   1588677.0
# Inner Richmond     ...       2128617.0   2124000.0   2110026.0   2101137.0
# Parkside           ...       1394726.0   1399913.0   1402299.0   1409094.0
#
#                 2019-10-31  2019-11-30  2019-12-31  2020-01-31  2020-02-29  \
# RegionName
# Outer Sunset     1374803.0   1386311.0   1403026.0   1411558.0   1420794.0
# Mission          1475606.0   1486465.0   1497416.0   1502307.0   1506689.0
# Outer Richmond   1595248.0   1605978.0   1619411.0   1628408.0   1635501.0
# Inner Richmond   2101688.0   2101768.0   2115011.0   2126079.0   2140365.0
# Parkside         1416884.0   1426611.0   1441516.0   1450781.0   1460379.0
#
#                 2020-03-31
# RegionName
# Outer Sunset     1426495.0
# Mission          1506592.0
# Outer Richmond   1638102.0
# Inner Richmond   2139254.0
# Parkside         1462524.0
#
# [5 rows x 293 columns]

# %%
sf_zillow.drop(["RegionType", "StateName"], axis = 1, inplace = True)

# %%
sf_zillow1 = sf_zillow.transpose()

# %%
sf_zillow1.head()
# Out:
# RegionName  Outer Sunset   Mission  Outer Richmond  Inner Richmond  Parkside  \
# 1996-01-31      281542.0  248722.0        364886.0        416245.0  299441.0
# 1996-02-29      280692.0  247234.0        363632.0        415703.0  298286.0
# 1996-03-31      280344.0  246912.0        363033.0        415728.0  297377.0
# 1996-04-30      279465.0  246186.0        361349.0        416848.0  295732.0
# 1996-05-31      278701.0  245295.0        360376.0        417485.0  294378.0
#
# RegionName  South of Market  Excelsior  Pacific Heights  Tenderloin  \
# 1996-01-31         262644.0   209909.0         455091.0    216446.0
# 1996-02-29         262066.0   209510.0         454598.0    213689.0
# 1996-03-31         261961.0   209208.0         454584.0    211608.0
#
# RegionName  Mount Davidson Manor  Balboa Terrace  Monterey Heights   Presidio  \
# 2019-11-30             1638326.0       2049797.0         2411906.0  2308574.0
# 2019-12-31             1660421.0       2074973.0         2453467.0  2354861.0
# 2020-01-31             1674464.0       2093830.0         2483358.0  2416418.0
# 2020-02-29             1692483.0       2107176.0         2511450.0  2494773.0
# 2020-03-31             1702852.0       2116110.0         2524995.0  2549839.0
#
# RegionName  Westwood Highlands
# 2019-11-30           1749456.0
# 2019-12-31           1770149.0
# 2020-01-31           1783436.0
# 2020-02-29           1801368.0
# 2020-03-31           1820287.0
#
# [5 rows x 75 columns]

# %%
len(sf_zillow1)
# Out:
# 291

# %%
sf_zillow1[['Outer Sunset', 'Mission', 'Tenderloin', 'Russian Hill', 'Lower Pacific Heights']].plot(figsize=(15,4))

# %% [markdown]
# ### above we can see the price trends for 5 of the SF neighborhoods we are looking at. We can tell that median house prices are generally increasing for all the neighborhoods, but it is hard to tell if there are any seasonality or other effects based solely on this plot ###

# %%
sf_zillow1.loc['2000-01-01':'2005-12-01', ['Outer Sunset', 'Mission', 'Tenderloin', 'Russian Hill', 'Lower Pacific Heights']].plot(figsize=(15,4))

# %% [markdown]
# ### based on the data visualization from 2000-2006 it doesn't seem to me like there is much seasonality with housing prices ###

# %% [markdown]
# ## Maybe a good idea to do a mathematical proof of seasonality test --> can look this up ##

# %% [markdown]
# ## Also look into some other time series data analysis --> resampling, periodicity and correlation, splitting and stacking cycles ##
#
# ## references:
# https://ourcodingclub.github.io/tutorials/pandas-time-series/
#
# https://medium.com/@feraguilari/time-series-analysis-modfinalproyect-b9fb23c28309

# %% [markdown]
# # Algorithm #

# %%
## We are going to use the Seasonal Auto-Regressive Integrated Moving Average (SARIMA) method to calulate future values.

## The SARIMA method requires that the data be stationary. In other words, it can't be increasing over time on average like 
## our data is doing.

## To account for this we can calculate the returns for each month and check to see if those are stationary.

# %%
sf_zillow.head()
# Out:
#                 1996-01-31  1996-02-29  1996-03-31  1996-04-30  1996-05-31  \
# RegionName
# Outer Sunset      281542.0    280692.0    280344.0    279465.0    278701.0
# Mission           248722.0    247234.0    246912.0    246186.0    245295.0
# Outer Richmond    364886.0    363632.0    363033.0    361349.0    360376.0
# Inner Richmond    416245.0    415703.0    415728.0    416848.0    417485.0
# Parkside          299441.0    298286.0    297377.0    295732.0    294378.0
#
#                 1996-06-30  1996-07-31  1996-08-31  1996-09-30  1996-10-31  \
# RegionName
# Outer Sunset      277975.0    277295.0    277477.0    277981.0    279338.0
# Mission           243570.0    241785.0    242816.0    245466.0    248257.0
# Outer Richmond    359990.0    360356.0    361147.0    361789.0    363587.0
# Inner Richmond    417173.0    415724.0    416227.0    418329.0    423102.0
# Parkside          293709.0    293359.0    294045.0    295174.0    296952.0
#
#                    ...      2019-06-30  2019-07-31  2019-08-31  2019-09-30  \
# RegionName         ...
# Outer Sunset       ...       1352307.0   1355850.0   1356184.0   1365300.0
# Mission            ...       1487391.0   1483819.0   1471945.0   1469175.0
# Outer Richmond     ...       1569494.0   1575815.0   1576816.0   1588677.0
# Inner Richmond     ...       2128617.0   2124000.0   2110026.0   2101137.0
# Parkside           ...       1394726.0   1399913.0   1402299.0   1409094.0
#
#                 2019-10-31  2019-11-30  2019-12-31  2020-01-31  2020-02-29  \
# RegionName
# Outer Sunset     1374803.0   1386311.0   1403026.0   1411558.0   1420794.0
# Mission          1475606.0   1486465.0   1497416.0   1502307.0   1506689.0
# Outer Richmond   1595248.0   1605978.0   1619411.0   1628408.0   1635501.0
# Inner Richmond   2101688.0   2101768.0   2115011.0   2126079.0   2140365.0
# Parkside         1416884.0   1426611.0   1441516.0   1450781.0   1460379.0
#
#                 2020-03-31
# RegionName
# Outer Sunset     1426495.0
# Mission          1506592.0
# Outer Richmond   1638102.0
# Inner Richmond   2139254.0
# Parkside         1462524.0
#
# [5 rows x 291 columns]

# %%
sf_zillow1.head()
# Out:
# 1996-01-31   NaN
# 1996-02-29   NaN
# 1996-03-31   NaN
# 1996-04-30   NaN
# 1996-05-31   NaN
# Name: Mission Bay, dtype: float64

# %% [markdown]
# ### Trial run with Outer Sunset ###

# %% [markdown]
# #### We will generalize after ####

# %%
districts[35]
# Out:
# 'Mission Bay'

# %%
trial = sf_zillow1[['Outer Sunset']]
trial = trial.reset_index()
#trial['returns'] = [(trial.loc[i, 'Outer Sunset'] - trial.loc[i-1, 'Outer Sunset']) / trial.loc[i, 'Outer Sunset'] for i in trial.index]

# %%
#trial = sf_zillow1[['Outer Sunset']]
#trial = trial.reset_index()

# %%
trial.head()
# Out:
# RegionName      index  Outer Sunset
# 0          1996-01-31      281542.0
# 1          1996-02-29      280692.0
# 2          1996-03-31      280344.0
# 3          1996-04-30      279465.0
# 4          1996-05-31      278701.0

# %%
returns = [0] + ([(trial.loc[i, 'Outer Sunset'] - trial.loc[i-1, 'Outer Sunset']) / trial.loc[i, 'Outer Sunset'] for i in range(1,len(trial))])

# %%
len(returns)
# Out:
# 291

# %%
len(trial)
# Out:
# 291

# %%
trial['returns'] = returns

# %%
trial.tail()
# Out:
# RegionName      index  Outer Sunset   returns
# 286        2019-11-30     1386311.0  0.008301
# 287        2019-12-31     1403026.0  0.011914
# 288        2020-01-31     1411558.0  0.006044
# 289        2020-02-29     1420794.0  0.006501
# 290        2020-03-31     1426495.0  0.003997

# %%
trial['returns'].plot()
print( np.mean(trial['returns']))
# Out:
# 0.005523789425245466

# %%
## It looks like the returns are stationary with no particular pattern of increasing or decreasing. Mean is close to 0
## We can perform the SARIMA method on returns
## The full justification requires looking at p-values (will do this later) --> Augmented Dickey-Fuller Test

# %%
#split into train and test sets
#preprocessing (since arima takes univariate series as input)
train_trial = trial[:int(0.7*(len(trial)))].drop(['index', 'Outer Sunset'], axis = 1)
test_trial = trial[int(0.7*(len(trial))):].drop(['index', 'Outer Sunset'], axis = 1)

# %%
##Returns
#returns = trial.drop(["index", "Outer Sunset"], axis = 1)
#returns.head()

# %%
##GENERALIZE
#train_trial = trial[:int(0.7*(len(trial)))].drop(['index', district], axis = 1)
#test_trial = trial[int(0.7*(len(trial))):].drop(['index', district], axis = 1)

# %%
train_trial['returns'].plot()
test_trial['returns'].plot()

# %%
#building the model
from pmdarima.arima import auto_arima
model = auto_arima(train_trial, trace=True, error_action='ignore', suppress_warnings=True)
model_fit = model.fit(train_trial)

forecast = model_fit.predict(n_periods=len(test_trial))
forecast = pd.DataFrame(forecast,index = test_trial.index,columns=['Prediction'])
# Out:
# Performing stepwise search to minimize aic
# Fit ARIMA: (2, 1, 2)x(0, 0, 0, 0) (constant=True); AIC=-1721.346, BIC=-1701.496, Time=0.634 seconds
# Fit ARIMA: (0, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=-1668.535, BIC=-1661.919, Time=0.105 seconds
# Fit ARIMA: (1, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=-1668.421, BIC=-1658.496, Time=0.078 seconds
# Fit ARIMA: (0, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=-1665.606, BIC=-1655.681, Time=0.068 seconds
# Fit ARIMA: (0, 1, 0)x(0, 0, 0, 0) (constant=False); AIC=-1670.466, BIC=-1667.158, Time=0.032 seconds
# Fit ARIMA: (1, 1, 2)x(0, 0, 0, 0) (constant=True); AIC=-1719.350, BIC=-1702.809, Time=0.322 seconds
# Fit ARIMA: (2, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=-1689.150, BIC=-1672.609, Time=0.435 seconds
# Fit ARIMA: (3, 1, 2)x(0, 0, 0, 0) (constant=True); AIC=-1713.030, BIC=-1689.872, Time=0.446 seconds
# Fit ARIMA: (2, 1, 3)x(0, 0, 0, 0) (constant=True); AIC=-1727.080, BIC=-1703.922, Time=0.229 seconds
# Fit ARIMA: (1, 1, 3)x(0, 0, 0, 0) (constant=True); AIC=-1751.691, BIC=-1731.841, Time=0.540 seconds
# Fit ARIMA: (0, 1, 3)x(0, 0, 0, 0) (constant=True); AIC=-1727.189, BIC=-1710.648, Time=0.088 seconds
# Fit ARIMA: (1, 1, 4)x(0, 0, 0, 0) (constant=True); AIC=-1745.309, BIC=-1722.152, Time=0.841 seconds
# Fit ARIMA: (0, 1, 2)x(0, 0, 0, 0) (constant=True); AIC=-1674.901, BIC=-1661.668, Time=0.386 seconds
# Fit ARIMA: (0, 1, 4)x(0, 0, 0, 0) (constant=True); AIC=-1752.049, BIC=-1732.199, Time=1.030 seconds
# Fit ARIMA: (0, 1, 5)x(0, 0, 0, 0) (constant=True); AIC=-1742.974, BIC=-1719.816, Time=1.623 seconds
# Fit ARIMA: (1, 1, 5)x(0, 0, 0, 0) (constant=True); AIC=-1737.887, BIC=-1711.421, Time=1.361 seconds
# Total fit time: 8.238 seconds

# %%
#forecast

# %%
##Plot predictions for test set
plt.plot(train_trial, label='Train')
plt.plot(test_trial, label='Valid')
plt.plot(forecast, label='Prediction')
plt.show()

# %%
#calculate rmse
from math import sqrt
from sklearn.metrics import mean_squared_error

rms = sqrt(mean_squared_error(test_trial,forecast))
print(rms)
# Out:
# 0.012221138647134207

# %%
len(test_trial) + (10*12)
# Out:
# 208

# %%
train_trial.tail()
# Out:
# RegionName   returns
# 198         0.017172
# 199         0.016138
# 200         0.016842
# 201         0.016234
# 202         0.014430

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
#making predictions
model_full = SARIMAX(train_trial, order=(1,0,1))
model_full_fit = model_full.fit()

output = model_full_fit.get_prediction(start=199, end = 207, dynamic = True)
forecast_ci = output.conf_int()

year_1= (1+output.predicted_mean[87:99]).prod()-1
year_3=(1+output.predicted_mean[99:135]).prod()-1
year_5= (1+output.predicted_mean[135:195]).prod()-1
year_10=(1+output.predicted_mean[87:]).prod()-1

yr10_forecast = model_fit.predict(n_periods = 207)
#yr10_forecast = pd.DataFrame(yr10_forecast,index = test_trial.index,columns=['Prediction'])

# %%
len(yr10_forecast)
# Out:
# 207

# %%
yr10_forecast
# Out:
# array([0.01349907, 0.01295361, 0.01401003, 0.01393122, 0.01399755,
#        0.01406388, 0.01413021, 0.01419655, 0.01426288, 0.01432921,
#        0.01439554, 0.01446188, 0.01452821, 0.01459454, 0.01466087,
#        0.01472721, 0.01479354, 0.01485987, 0.0149262 , 0.01499254,
#        0.01505887, 0.0151252 , 0.01519153, 0.01525787, 0.0153242 ,
#  'Potrero Hill',
#  'Noe Valley',
#  'Russian Hill',
#  'Inner Sunset',
#  'Crocker Amazon',
#  'Visitacion Valley',
#  'Golden Gate Heights',
#  'Marina',
#  'Ingleside',
#  'Mission Terrace',
#  'Parkmerced',
#  'Silver Terrace',
#  'Oceanview',
#  'North Beach',
#  'Lone Mountain',
#  'Chinatown',
#  'Sunnyside',
#  'Outer Mission',
#  'Panhandle',
#  'Buena Vista',
#  'Ingleside Heights',
#  'Mission Bay',
#  'Lower Pacific Heights',
#  'South Beach',
#  'Haight',
#  'Duboce Triangle',
#  'Presidio Heights',
#  'Laurel Heights',
#  'Hayes Valley',
#  'Upper Market',
#  'Miraloma Park',
#  'Lakeshore',
#  'Hunters Point',
#  'Cow Hollow',
#  'Glen Park',
#  'Alamo Square',
#  'Telegraph Hill',
#  'Financial District',
#  'Lake',
#  'Downtown',
#  'Diamond Heights',
#  'Stonestown',
#  'Clarendon Heights',
#  'Anza Vista',
#  'Merced Manor',
#  'Westwood Park',
#  'Sherwood Forest',
#  'Ingleside Terrace',
#  'Forest Hill',
#  'Corona Heights',
#  'Midtown Terrace',
#  'Little Hollywood',
#  'North Waterfront',
#  'Forest Knolls',
#  'Seacliff',
#  'St. Francis Wood',
#  'Mount Davidson Manor',
#  'Balboa Terrace',
#  'Monterey Heights',
#  'Presidio',
#  'Westwood Highlands']

# %%
##Export Prediction Function for External Use

# %%
def medianPred(district, currentVal):
    ##Include most of the above model in this space; leave for now
    
    
    trial = sf_zillow1[[district]]
    trial = trial.reset_index()
    
    
    returns = [0] + ([(trial.loc[i, district] - trial.loc[i-1, district]) / trial.loc[i, district] for i in range(1,len(trial))])
    
    trial['returns'] = returns
    
    
    #train_trial = trial[:int(0.7*(len(trial)))].drop(['index', district], axis = 1)
    #test_trial = trial[int(0.7*(len(trial))):].drop(['index', district], axis = 1)
    
    returns = trial.drop(["index", district], axis = 1)
    
    ##Creating the Model
    model = auto_arima(returns, trace=True, error_action='ignore', suppress_warnings=True)
    model_fit = model.fit(returns)

    forecast = model_fit.predict(n_periods = 240)##240
    #forecast = pd.DataFrame(forecast,index = test_trial.index,columns=['Prediction'])
    
    ##Plot predictions for test set
    plt.plot(train_trial, label='Train')
    plt.plot(test_trial, label='Valid')
    plt.plot(forecast, label='Prediction')
    plt.show()
    
    ##Error
    #from math import sqrt
    #from sklearn.metrics import mean_squared_error

    #rms = sqrt(mean_squared_error(test_trial,forecast))
    
    
   # from statsmodels.tsa.statespace.sarimax import SARIMAX
    ##Predictions
    #model_full = SARIMAX(train_trial, order=(1,0,1))
    #model_full_fit = model_full.fit()

    #output = model_full_fit.get_prediction(start=207, end = 327, dynamic = True)
    #forecast_ci = output.conf_int()

    #year_1= (1+output.predicted_mean[87:99]).prod()-1
    #year_3=(1+output.predicted_mean[99:135]).prod()-1
    #year_5= (1+output.predicted_mean[135:195]).prod()-1
    #year_10=(1+output.predicted_mean[87:]).prod()-1
    
    #yr10_forecast = model_fit.predict(n_periods = 291)
    returns_new = [1 + i for i in returns["returns"]]
    
    year_1 = np.prod(returns_new[:12])
    year_3 = np.prod(returns_new[:36])
    year_5 = np.prod(returns_new[:60])
    year_10 = np.prod(returns_new[:120])
    year_20 = np.prod(returns_new[:240])

    yearReturns = [year_1, year_3, year_5, year_10, year_20]
    
    #valuationForecast = [currentVal * year for year in yearReturns]
    return yearReturns
    #return valuationForecast

# %%
outerSun = medianPred("Outer Sunset", 100000)
outerSun
# Out:
# Performing stepwise search to minimize aic
# Fit ARIMA: (2, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-2383.694, BIC=-2361.654, Time=0.527 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-1939.651, BIC=-1932.304, Time=0.072 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-2341.286, BIC=-2330.266, Time=0.106 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-2124.254, BIC=-2113.234, Time=0.180 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=-1840.706, BIC=-1837.032, Time=0.025 seconds
# Fit ARIMA: (1, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-2349.769, BIC=-2331.402, Time=0.192 seconds
# Fit ARIMA: (2, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-2347.133, BIC=-2328.766, Time=0.421 seconds
# Fit ARIMA: (3, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-2385.769, BIC=-2360.056, Time=0.633 seconds
# Fit ARIMA: (3, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-2356.415, BIC=-2334.375, Time=0.942 seconds
# Fit ARIMA: (4, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-2379.421, BIC=-2350.035, Time=0.885 seconds
# Fit ARIMA: (3, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-2416.742, BIC=-2387.355, Time=0.697 seconds
# Fit ARIMA: (2, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-2393.539, BIC=-2367.826, Time=0.242 seconds
# Fit ARIMA: (4, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-2421.786, BIC=-2388.726, Time=0.762 seconds
# Fit ARIMA: (5, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-2371.023, BIC=-2334.290, Time=1.965 seconds
# Fit ARIMA: (4, 0, 4)x(0, 0, 0, 0) (constant=True); AIC=-2408.062, BIC=-2371.328, Time=1.828 seconds
# Fit ARIMA: (3, 0, 4)x(0, 0, 0, 0) (constant=True); AIC=-2424.487, BIC=-2391.427, Time=1.200 seconds
# Fit ARIMA: (2, 0, 4)x(0, 0, 0, 0) (constant=True); AIC=-2387.781, BIC=-2358.394, Time=0.572 seconds
# Fit ARIMA: (3, 0, 5)x(0, 0, 0, 0) (constant=True); AIC=-2378.623, BIC=-2341.890, Time=1.750 seconds
# Fit ARIMA: (2, 0, 5)x(0, 0, 0, 0) (constant=True); AIC=-2442.352, BIC=-2409.292, Time=0.969 seconds
# Fit ARIMA: (1, 0, 5)x(0, 0, 0, 0) (constant=True); AIC=-2389.779, BIC=-2360.393, Time=0.304 seconds
# Fit ARIMA: (1, 0, 4)x(0, 0, 0, 0) (constant=True); AIC=-2421.801, BIC=-2396.088, Time=0.842 seconds
# Total fit time: 15.135 seconds
# [1.003763950869951,
#  1.2832688553054625,
#  1.764364042486087,
#  2.8802064177943234,
#  3.867914812941633]

# %%
outerSun
# Out:
# [1.003763950869951,
#  1.2832688553054625,
#  1.764364042486087,
#  2.8802064177943234,
#  3.867914812941633]

# %%
len(districts)
# Out:
# 75

# %%
#districts

# %%
medianPred("Mission", 100000)
# Out:
# Performing stepwise search to minimize aic
# Fit ARIMA: (2, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-2313.909, BIC=-2291.869, Time=0.586 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-1853.553, BIC=-1846.206, Time=0.073 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-2232.365, BIC=-2221.345, Time=0.128 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-2041.442, BIC=-2030.422, Time=0.313 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=-1762.088, BIC=-1758.414, Time=0.027 seconds
# Fit ARIMA: (1, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-2280.002, BIC=-2261.636, Time=0.429 seconds
# Fit ARIMA: (2, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-2232.295, BIC=-2213.928, Time=0.630 seconds
# Fit ARIMA: (3, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-2282.860, BIC=-2257.147, Time=0.771 seconds
# Fit ARIMA: (2, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-2326.958, BIC=-2301.245, Time=0.907 seconds
# Fit ARIMA: (1, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-2299.303, BIC=-2277.263, Time=0.189 seconds
# Fit ARIMA: (3, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-2292.025, BIC=-2262.638, Time=0.101 seconds
# Fit ARIMA: (2, 0, 4)x(0, 0, 0, 0) (constant=True); AIC=-2293.663, BIC=-2264.276, Time=0.653 seconds
# Fit ARIMA: (1, 0, 4)x(0, 0, 0, 0) (constant=True); AIC=-2296.333, BIC=-2270.620, Time=0.629 seconds
# Fit ARIMA: (3, 0, 4)x(0, 0, 0, 0) (constant=True); AIC=-2311.646, BIC=-2278.586, Time=2.238 seconds
# Total fit time: 7.689 seconds
# [1.007322331031294,
#  1.2920215673894835,
#  2.1002373807221235,
#  3.181203464498365,
#  4.763388911333756]

# %%
##medianPred(districts[3])

# %%
import pickle

# %%
districtOut = dict()

# %%
for i in districts[2:]:
    districtOut[i] = medianPred(i, 100000)
# Out:
# Performing stepwise search to minimize aic
# Fit ARIMA: (2, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-2385.652, BIC=-2363.612, Time=0.548 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-1961.820, BIC=-1954.473, Time=0.082 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-2308.179, BIC=-2297.159, Time=0.121 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-2132.064, BIC=-2121.044, Time=0.293 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=-1869.377, BIC=-1865.704, Time=0.029 seconds
# Fit ARIMA: (1, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-2357.539, BIC=-2339.173, Time=0.785 seconds
# Fit ARIMA: (2, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-
seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=-1787.065, BIC=-1783.391, Time=0.026 seconds
# Fit ARIMA: (1, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-2268.600, BIC=-2250.233, Time=0.444 seconds
# Fit ARIMA: (0, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-2260.366, BIC=-2245.672, Time=0.211 seconds
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-2199.165, BIC=-2184.472, Time=0.135 seconds
# Fit ARIMA: (1, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-2312.482, BIC=-2290.442, Time=1.031 seconds
# Fit ARIMA: (0, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-2289.964, BIC=-2271.598, Time=0.870 seconds
# Near non-invertible roots for order (0, 0, 3)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.995)
# Fit ARIMA: (2, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-2316.714, BIC=-2291.001, Time=1.140 seconds
# Fit ARIMA: (3, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-2305.851, BIC=-2276.464, Time=0.660 seconds
# Fit ARIMA: (2, 0, 4)x(0, 0, 0, 0) (constant=True); AIC=-2300.792, BIC=-2271.405, Time=0.730 seconds
# Fit ARIMA: (1, 0, 4)x(0, 0, 0, 0) (constant=True); AIC=-2322.280, BIC=-2296.567, Time=0.663 seconds
# Near non-invertible roots for order (1, 0, 4)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.991)
# Fit ARIMA: (3, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-2274.092, BIC=-2248.379, Time=0.601 seconds
# Fit ARIMA: (3, 0, 4)x(0, 0, 0, 0) (constant=True); AIC=-2301.553, BIC=-2268.493, Time=1.196 seconds
# Total fit time: 8.177 seconds
# Performing stepwise search to minimize aic
# Fit ARIMA: (2, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-2350.803, BIC=-2328.763, Time=0.894 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-1884.585, BIC=-1877.238, Time=0.073 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-2255.628, BIC=-2244.608, Time=0.099 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-2070.639, BIC=-2059.619, Time=0.212 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=-1791.561, BIC=-1787.888, Time=0.027 seconds
# Fit ARIMA: (1, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-2336.733, BIC=-2318.366, Time=0.444 seconds
# Fit ARIMA: (2, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-2253.563, BIC=-2235.197, Time=0.407 seconds
# Fit ARIMA: (3, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-2319.575, BIC=-2293.862, Time=0.598 seconds
# Fit ARIMA: (2, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-2363.920, BIC=-2338.206, Time=0.613 seconds
# Fit ARIMA: (1, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-2331.718, BIC=-2309.678, Time=0.433 seconds
# Fit ARIMA: (3, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-2360.700, BIC=-2331.314, Time=0.850 seconds
# Fit ARIMA: (2, 0, 4)x(0, 0, 0, 0) (constant=True); AIC=-2343.284, BIC=-2313.897, Time=0.930 seconds
# Fit ARIMA: (1, 0, 4)x(0, 0, 0, 0) (constant=True); AIC=-2375.031, BIC=-2349.317, Time=0.817 seconds
# Near non-invertible roots for order (1, 0, 4)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.995)
# Fit ARIMA: (3, 0, 4)x(0, 0, 0, 0) (constant=True); AIC=-2366.393, BIC=-2333.333, Time=1.001 seconds
# Fit ARIMA: (4, 0, 4)x(0, 0, 0, 0) (constant=True); AIC=-2346.118, BIC=-2309.385, Time=1.669 seconds
# Fit ARIMA: (3, 0, 5)x(0, 0, 0, 0) (constant=True); AIC=-2379.315, BIC=-2342.582, Time=1.874 seconds
# Fit ARIMA: (2, 0, 5)x(0, 0, 0, 0) (constant=True); AIC=-2369.186, BIC=-2336.126, Time=1.442 seconds
# Fit ARIMA: (4, 0, 5)x(0, 0, 0, 0) (constant=True); AIC=-2299.749, BIC=-2259.343, Time=0.335 seconds
# Total fit time: 12.735 seconds
# Performing stepwise search to minimize aic
# Fit ARIMA: (2, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-2261.157, BIC=-2239.117, Time=0.517 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-1841.258, BIC=-1833.912, Time=0.072 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-2222.608, BIC=-2211.588, Time=0.097 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-2023.261, BIC=-2012.241, Time=0.191 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=-1765.369, BIC=-1761.696, Time=0.029 seconds
# Fit ARIMA: (1, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-2285.886, BIC=-2267.520, Time=0.482 seconds
# Near non-invertible roots for order (1, 0, 2)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.991)
# Fit ARIMA: (2, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-2225.807, BIC=-2207.441, Time=0.474 seconds
# Fit ARIMA: (3, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-2234.492, BIC=-2208.778, Time=0.461 seconds
# Fit ARIMA: (2, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-2289.969, BIC=-2264.256, Time=0.213 seconds
# Fit ARIMA: (1, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-2329.516, BIC=-2307.476, Time=0.609 seconds
# Near non-invertible roots for order (1, 0, 3)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.992)
# Fit ARIMA: (3, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-2291.773, BIC=-2262.386, Time=0.908 seconds
# Fit ARIMA: (4, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-2316.317, BIC=-2283.257, Time=1.501 seconds
# Fit ARIMA: (4, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-2267.285, BIC=-2237.899, Time=0.593 seconds
# Fit ARIMA: (5, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-2262.359, BIC=-2225.626, Time=1.951 seconds
# Fit ARIMA: (4, 0, 4)x(0, 0, 0, 0) (constant=True); AIC=-2313.929, BIC=-2277.196, Time=1.672 seconds
# Fit ARIMA: (3, 0, 4)x(0, 0, 0, 0) (constant=True); AIC=-2313.049, BIC=-2279.989, Time=1.549 seconds
# Fit ARIMA: (5, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-2286.425, BIC=-2253.365, Time=1.655 seconds
# Fit ARIMA: (5, 0, 4)x(0, 0, 0, 0) (constant=True); AIC=-2273.111, BIC=-2232.704, Time=0.699 seconds
# Total fit time: 13.695 seconds
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-599926dc9119> in <module>
#       1 for i in districts[2:]:
# ----> 2     districtOut[i] = medianPred(i, 100000)
#       3
#
# <ipython-input-34-430c38f23524> in medianPred(district, currentVal)
#      18
#      19     ##Creating the Model
# ---> 20     model = auto_arima(returns, trace=True, error_action='ignore', suppress_warnings=True)
#      21     model_fit = model.fit(returns)
#      22
#
# /srv/app/venv/lib/python3.6/site-packages/pmdarima/arima/auto.py in auto_arima(y, exogenous, start_p, d, start_q, max_p, max_d, max_q, start_P, D, start_Q, max_P, max_D, max_Q, max_order, m, seasonal, stationary, information_criterion, alpha, test, seasonal_test, stepwise, n_jobs, start_params, trend, method, maxiter, offset_test_args, seasonal_test_args, suppress_warnings, error_action, trace, random, random_state, n_fits, return_valid_fits, out_of_sample_size, scoring, scoring_args, with_intercept, sarimax_kwargs, **fit_args)
#     434         offset_test_args = offset_test_args \
#     435             if offset_test_args is not None else dict()
# --> 436         d = ndiffs(dx, test=test, alpha=alpha, max_d=max_d, **offset_test_args)
#     437
#     438         if d > 0 and exogenous is not None:
#
# /srv/app/venv/lib/python3.6/site-packages/pmdarima/arima/utils.py in ndiffs(x, alpha, test, max_d, **kwargs)
#     163
#     164     # get initial diff
# --> 165     pval, dodiff = testfunc(x)
#     166
#     167     # if initially NaN, return 0
#
# /srv/app/venv/lib/python3.6/site-packages/pmdarima/arima/stationarity.py in should_diff(self, x)
#     184
#     185         # fit the model
# --> 186         lm = LinearRegression().fit(t, x)
#     187         e = x - lm.predict(t)  # residuals
#     188
#
# /srv/app/venv/lib/python3.6/site-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     490         n_jobs_ = self.n_jobs
#     491         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 492                          y_numeric=True, multi_output=True)
#     493
#     494         if sample_weight is not None:
#
# /srv/app/venv/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     756     if multi_output:
#     757         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
# --> 758                         dtype=None)
#     759     else:
#     760         y = column_or_1d(y, warn=True)
#
# /srv/app/venv/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     576         if force_all_finite:
#     577             _assert_all_finite(array,
# --> 578                                allow_nan=force_all_finite == 'allow-nan')
#     579
#     580     if ensure_min_samples > 0:
#
# /srv/app/venv/lib/python3.6/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      58                     msg_err.format
#      59                     (type_err,
# ---> 60                      msg_dtype if msg_dtype is not None else X.dtype)
#      61             )
#      62     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
for i in districts[36:]:
    districtOut[i] = medianPred(i, 100000)
# Out:
# Performing stepwise search to minimize aic
# Fit ARIMA: (2, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-2340.394, BIC=-2318.354, Time=0.650 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-1918.173, BIC=-1910.826, Time=0.119 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-2251.001, BIC=-2239.981, Time=0.106 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-2109.625, BIC=-2098.605, Time=0.301 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=-1824.723, BIC=-1821.050, Time=0.045 seconds
# Fit ARIMA: (1, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-2354.824, BIC=-2336.458, Time=0.510 seconds
# Near non-invertible roots for order (1, 0, 2)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.995)
# Fit ARIMA: (2, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-2247.835, BIC=-2229.469, Time=0.360 seconds
# Fit ARIMA: (3, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-2299.097, BIC=-2273.384, Time=0.569 seconds
# Fit ARIMA: (2, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-2366.458, BIC=-2340.745, Time=0.590 seconds
# Fit ARIMA: (1, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-2330.224, BIC=-2308.184, Time=0.227 seconds
# Fit ARIMA: (3, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-2364.810, BIC=-2335.423, Time=0.647 seconds
# Fit ARIMA: (2, 0, 4)x(0, 0, 0, 0) (constant=True); AIC=-2366.782, BIC=-2337.395, Time=1.065 seconds
# Fit ARIMA: (1, 0, 4)x(0, 0, 0, 0) (constant=True); AIC=-2357.222, BIC=-2331.509, Time=1.120 seconds
# Fit ARIMA: (3, 0, 4)x(0, 0, 0, 0) (constant=True); AIC=-2374.952, BIC=-2341.893, Time=1.716 seconds
# Near non-invertible roots for order (3, 0, 4)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.993)
# Fit ARIMA: (2, 0, 5)x(0, 0, 0, 0) (constant=True); AIC=-2331.256, BIC=-2298.196, Time=0.617 seconds
# Fit ARIMA: (1, 0, 5)x(0, 0, 0, 0) (constant=True); AIC=-2334.870, BIC=-2305.484, Time=0.740 seconds
# Fit ARIMA: (3, 0, 5)x(0, 0, 0, 0) (constant=True); AIC=-2387.333, BIC=-2350.600, Time=1.918 seconds
# Near non-invertible roots for order (3, 0, 5)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.998)
# Total fit time: 11.318 seconds
# Performing stepwise search to minimize aic
# Fit ARIMA: (2, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-2359.377, BIC=-2337.337, Time=0.999 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-1912.948, BIC=-1905.602, Time=0.117 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-2282.281, BIC=-2271.261, Time=0.189 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-2089.467, BIC=-2078.447, Time=0.270 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=-1830.305, BIC=-1826.631, Time=0.029 seconds
# Fit ARIMA: (1, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-2295.295, BIC=-2276.929, Time=0.376 seconds
# Fit ARIMA: (2, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-2286.687, BIC=-2268.320, Time=0.446 seconds
# Fit ARIMA: (3, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-2334.251, BIC=-2308.538, Time=0.587 seconds
# Fit ARIMA: (2, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-2378.666, BIC=-2352.953, Time=0.878 seconds
# Fit ARIMA: (1, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-2384.299, BIC=-2362.259, Time=0.613 seconds
# Fit ARIMA: (0, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-2343.576, BIC=-2325.210, Time=0.521 seconds
# Near non-invertible roots for order (0, 0, 3)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.991)
# Fit ARIMA: (1, 0, 4)x(0, 0, 0, 0) (constant=True); AIC=-2351.323, BIC=-2325.610, Time=0.563 seconds
# Fit ARIMA: (0, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-2336.039, BIC=-2321.346, Time=0.381 seconds
# Near non-invertible roots for order (0, 0, 2)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Fit ARIMA: (0, 0, 4)x(0, 0, 0, 0) (constant=True); AIC=-2329.197, BIC=-2307.158, Time=0.611 seconds
# Fit ARIMA: (2, 0, 4)x(0, 0, 0, 0) (constant=True); AIC=-2347.073, BIC=-2317.686, Time=0.204 seconds
# Total fit time: 6.799 seconds
# Performing stepwise search to minimize aic
# Fit ARIMA: (2, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-
seconds
# Fit ARIMA: (2, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=-2173.686, BIC=-2155.337, Time=0.157 seconds
# Fit ARIMA: (3, 1, 2)x(0, 0, 0, 0) (constant=True); AIC=-2251.076, BIC=-2225.387, Time=0.412 seconds
# Fit ARIMA: (3, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=-2248.542, BIC=-2226.522, Time=0.126 seconds
# Fit ARIMA: (4, 1, 2)x(0, 0, 0, 0) (constant=True); AIC=-2246.267, BIC=-2216.908, Time=0.836 seconds
# Fit ARIMA: (3, 1, 3)x(0, 0, 0, 0) (constant=True); AIC=-2294.430, BIC=-2265.071, Time=0.793 seconds
# Fit ARIMA: (2, 1, 3)x(0, 0, 0, 0) (constant=True); AIC=-2266.274, BIC=-2240.584, Time=0.257 seconds
# Fit ARIMA: (4, 1, 3)x(0, 0, 0, 0) (constant=True); AIC=-2258.948, BIC=-2225.919, Time=0.666 seconds
# Fit ARIMA: (3, 1, 4)x(0, 0, 0, 0) (constant=True); AIC=-2255.847, BIC=-2222.818, Time=0.402 seconds
# Fit ARIMA: (2, 1, 4)x(0, 0, 0, 0) (constant=True); AIC=-2229.142, BIC=-2199.783, Time=0.807 seconds
# Fit ARIMA: (4, 1, 4)x(0, 0, 0, 0) (constant=True); AIC=-2256.613, BIC=-2219.914, Time=0.985 seconds
# Total fit time: 6.682 seconds
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-8eafe172bf9a> in <module>
#       1 for i in districts[36:]:
# ----> 2     districtOut[i] = medianPred(i, 100000)
#
# <ipython-input-34-430c38f23524> in medianPred(district, currentVal)
#      18
#      19     ##Creating the Model
# ---> 20     model = auto_arima(returns, trace=True, error_action='ignore', suppress_warnings=True)
#      21     model_fit = model.fit(returns)
#      22
#
# /srv/app/venv/lib/python3.6/site-packages/pmdarima/arima/auto.py in auto_arima(y, exogenous, start_p, d, start_q, max_p, max_d, max_q, start_P, D, start_Q, max_P, max_D, max_Q, max_order, m, seasonal, stationary, information_criterion, alpha, test, seasonal_test, stepwise, n_jobs, start_params, trend, method, maxiter, offset_test_args, seasonal_test_args, suppress_warnings, error_action, trace, random, random_state, n_fits, return_valid_fits, out_of_sample_size, scoring, scoring_args, with_intercept, sarimax_kwargs, **fit_args)
#     434         offset_test_args = offset_test_args \
#     435             if offset_test_args is not None else dict()
# --> 436         d = ndiffs(dx, test=test, alpha=alpha, max_d=max_d, **offset_test_args)
#     437
#     438         if d > 0 and exogenous is not None:
#
# /srv/app/venv/lib/python3.6/site-packages/pmdarima/arima/utils.py in ndiffs(x, alpha, test, max_d, **kwargs)
#     163
#     164     # get initial diff
# --> 165     pval, dodiff = testfunc(x)
#     166
#     167     # if initially NaN, return 0
#
# /srv/app/venv/lib/python3.6/site-packages/pmdarima/arima/stationarity.py in should_diff(self, x)
#     184
#     185         # fit the model
# --> 186         lm = LinearRegression().fit(t, x)
#     187         e = x - lm.predict(t)  # residuals
#     188
#
# /srv/app/venv/lib/python3.6/site-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     490         n_jobs_ = self.n_jobs
#     491         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 492                          y_numeric=True, multi_output=True)
#     493
#     494         if sample_weight is not None:
#
# /srv/app/venv/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     756     if multi_output:
#     757         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
# --> 758                         dtype=None)
#     759     else:
#     760         y = column_or_1d(y, warn=True)
#
# /srv/app/venv/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     576         if force_all_finite:
#     577             _assert_all_finite(array,
# --> 578                                allow_nan=force_all_finite == 'allow-nan')
#     579
#     580     if ensure_min_samples > 0:
#
# /srv/app/venv/lib/python3.6/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      58                     msg_err.format
#      59                     (type_err,
# ---> 60                      msg_dtype if msg_dtype is not None else X.dtype)
#      61             )
#      62     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
for i in districts[54:]:
    districtOut[i] = medianPred(i, 100000)
# Out:
# Performing stepwise search to minimize aic
# Fit ARIMA: (2, 1, 2)x(0, 0, 0, 0) (constant=True); AIC=-2188.613, BIC=-2166.594, Time=0.158 seconds
# Fit ARIMA: (0, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=-2187.176, BIC=-2179.836, Time=0.083 seconds
# Fit ARIMA: (1, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=-2190.011, BIC=-2179.002, Time=0.093 seconds
# Fit ARIMA: (0, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=-2189.436, BIC=-2178.427, Time=0.128 seconds
# Fit ARIMA: (0, 1, 0)x(0, 0, 0, 0) (constant=False); AIC=-2189.172, BIC=-2185.502, Time=0.114 seconds
# Fit ARIMA: (2, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=-2189.163, BIC=-2174.484, Time=0.329 seconds
# Fit ARIMA: (1, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=-
seconds
# Fit ARIMA: (2, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-2251.994, BIC=-2226.280, Time=0.186 seconds
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-2166.674, BIC=-2151.981, Time=0.123 seconds
# Fit ARIMA: (1, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-2280.164, BIC=-2258.124, Time=0.527 seconds
# Fit ARIMA: (0, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-2250.098, BIC=-2231.731, Time=0.866 seconds
# Fit ARIMA: (1, 0, 4)x(0, 0, 0, 0) (constant=True); AIC=-2276.688, BIC=-2250.974, Time=1.285 seconds
# Fit ARIMA: (0, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-2235.208, BIC=-2220.515, Time=0.392 seconds
# Fit ARIMA: (0, 0, 4)x(0, 0, 0, 0) (constant=True); AIC=-2220.194, BIC=-2198.154, Time=1.008 seconds
# Fit ARIMA: (2, 0, 4)x(0, 0, 0, 0) (constant=True); AIC=-2277.495, BIC=-2248.108, Time=1.091 seconds
# Total fit time: 8.303 seconds
# Performing stepwise search to minimize aic
# Fit ARIMA: (2, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-2273.013, BIC=-2250.973, Time=0.494 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-1855.707, BIC=-1848.360, Time=0.067 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-2185.618, BIC=-2174.598, Time=0.106 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-2020.397, BIC=-2009.377, Time=0.209 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=-1777.183, BIC=-1773.510, Time=0.026 seconds
# Fit ARIMA: (1, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-2263.230, BIC=-2244.863, Time=0.516 seconds
# Fit ARIMA: (2, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-2186.905, BIC=-2168.538, Time=0.360 seconds
# Fit ARIMA: (3, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-2251.983, BIC=-2226.270, Time=0.587 seconds
# Fit ARIMA: (2, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-2295.652, BIC=-2269.939, Time=1.214 seconds
# Fit ARIMA: (1, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-2271.770, BIC=-2249.730, Time=0.634 seconds
# Fit ARIMA: (3, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-2291.120, BIC=-2261.733, Time=0.665 seconds
# Fit ARIMA: (2, 0, 4)x(0, 0, 0, 0) (constant=True); AIC=-2299.010, BIC=-2269.623, Time=1.308 seconds
# Fit ARIMA: (1, 0, 4)x(0, 0, 0, 0) (constant=True); AIC=-2274.135, BIC=-2248.422, Time=0.874 seconds
# Fit ARIMA: (3, 0, 4)x(0, 0, 0, 0) (constant=True); AIC=-2280.426, BIC=-2247.366, Time=1.520 seconds
# Fit ARIMA: (2, 0, 5)x(0, 0, 0, 0) (constant=True); AIC=-2286.095, BIC=-2253.035, Time=1.441 seconds
# Fit ARIMA: (1, 0, 5)x(0, 0, 0, 0) (constant=True); AIC=-2258.071, BIC=-2228.684, Time=0.630 seconds
# Fit ARIMA: (3, 0, 5)x(0, 0, 0, 0) (constant=True); AIC=-2299.571, BIC=-2262.838, Time=1.910 seconds
# Fit ARIMA: (4, 0, 5)x(0, 0, 0, 0) (constant=True); AIC=-2261.459, BIC=-2221.052, Time=2.192 seconds
# Fit ARIMA: (4, 0, 4)x(0, 0, 0, 0) (constant=True); AIC=-2257.018, BIC=-2220.285, Time=0.528 seconds
# Total fit time: 15.303 seconds
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-fc2f1a5712e8> in <module>
#       1 for i in districts[54:]:
# ----> 2     districtOut[i] = medianPred(i, 100000)
#
# <ipython-input-34-430c38f23524> in medianPred(district, currentVal)
#      18
#      19     ##Creating the Model
# ---> 20     model = auto_arima(returns, trace=True, error_action='ignore', suppress_warnings=True)
#      21     model_fit = model.fit(returns)
#      22
#
# /srv/app/venv/lib/python3.6/site-packages/pmdarima/arima/auto.py in auto_arima(y, exogenous, start_p, d, start_q, max_p, max_d, max_q, start_P, D, start_Q, max_P, max_D, max_Q, max_order, m, seasonal, stationary, information_criterion, alpha, test, seasonal_test, stepwise, n_jobs, start_params, trend, method, maxiter, offset_test_args, seasonal_test_args, suppress_warnings, error_action, trace, random, random_state, n_fits, return_valid_fits, out_of_sample_size, scoring, scoring_args, with_intercept, sarimax_kwargs, **fit_args)
#     434         offset_test_args = offset_test_args \
#     435             if offset_test_args is not None else dict()
# --> 436         d = ndiffs(dx, test=test, alpha=alpha, max_d=max_d, **offset_test_args)
#     437
#     438         if d > 0 and exogenous is not None:
#
# /srv/app/venv/lib/python3.6/site-packages/pmdarima/arima/utils.py in ndiffs(x, alpha, test, max_d, **kwargs)
#     163
#     164     # get initial diff
# --> 165     pval, dodiff = testfunc(x)
#     166
#     167     # if initially NaN, return 0
#
# /srv/app/venv/lib/python3.6/site-packages/pmdarima/arima/stationarity.py in should_diff(self, x)
#     184
#     185         # fit the model
# --> 186         lm = LinearRegression().fit(t, x)
#     187         e = x - lm.predict(t)  # residuals
#     188
#
# /srv/app/venv/lib/python3.6/site-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     490         n_jobs_ = self.n_jobs
#     491         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 492                          y_numeric=True, multi_output=True)
#     493
#     494         if sample_weight is not None:
#
# /srv/app/venv/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     756     if multi_output:
#     757         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
# --> 758                         dtype=None)
#     759     else:
#     760         y = column_or_1d(y, warn=True)
#
# /srv/app/venv/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     576         if force_all_finite:
#     577             _assert_all_finite(array,
# --> 578                                allow_nan=force_all_finite == 'allow-nan')
#     579
#     580     if ensure_min_samples > 0:
#
# /srv/app/venv/lib/python3.6/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      58                     msg_err.format
#      59                     (type_err,
# ---> 60                      msg_dtype if msg_dtype is not None else X.dtype)
#      61             )
#      62     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
for i in districts[74:]:
    districtOut[i] = medianPred(i, 100000)
# Out:
# Performing stepwise search to minimize aic
# Fit ARIMA: (2, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-2241.301, BIC=-2219.261, Time=1.180 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-1838.795, BIC=-1831.448, Time=0.125 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-2149.931, BIC=-2138.911, Time=0.101 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-1992.047, BIC=-1981.027, Time=0.282 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=-1768.191, BIC=-1764.517, Time=0.027 seconds
# Fit ARIMA: (1, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-2226.236, BIC=-2207.869, Time=0.880 seconds
# Fit ARIMA: (2, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-2154.745, BIC=-2136.378, Time=0.542 seconds
# Fit ARIMA: (3, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-2230.163, BIC=-2204.449, Time=0.949 seconds
# Fit ARIMA: (2, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-2262.096, BIC=-2236.383, Time=0.969 seconds
# Fit ARIMA: (1, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-2263.514, BIC=-2241.474, Time=0.963 seconds
# Fit ARIMA: (0, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-2240.472, BIC=-2222.105, Time=0.459 seconds
# Fit ARIMA: (1, 0, 4)x(0, 0, 0, 0) (constant=True); AIC=-2260.732, BIC=-2235.018, Time=1.002 seconds
# Fit ARIMA: (0, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-2240.341, BIC=-2225.648, Time=0.429 seconds
# Fit ARIMA: (0, 0, 4)x(0, 0, 0, 0) (constant=True); AIC=-2243.613, BIC=-2221.573, Time=1.244 seconds
# Fit ARIMA: (2, 0, 4)x(0, 0, 0, 0) (constant=True); AIC=-2261.074, BIC=-2231.688, Time=2.445 seconds
# Near non-invertible roots for order (2, 0, 4)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.990)
# Total fit time: 11.616 seconds

# %%
districts[35]
# Out:
# 'Mission Bay'

# %%
districts[53]
# Out:
# 'Downtown'

# %%
districts[73]
# Out:
# 'Presidio'

# %%
len(districtOut)
# Out:
# 72

# %%
districtOut
# Out:
# {'Outer Sunset': [1.003763950869951,
#   1.2832688553054625,
#   1.764364042486087,
#   2.8802064177943234,
#   3.867914812941633],
#  'Mission': [1.007322331031294,
#   1.2920215673894835,
#   2.1002373807221235,
#   3.181203464498365,
#   4.763388911333756],
#  'Outer Richmond': [1.0075020564029653,
#   1.281245391933454,
#   1.7570853184057966,
#   2.699921656714194,
#   3.5403487766004536],
#  'Inner Richmond': [1.0374474587329836,
#   1.3420657052484142,
#   1.914155009148604,
#   3.0273866686994664,
#   3.9351176943973525],
#  'Parkside': [1.005610640307213,
#   1.306468093561672,
#   1.7840272796409267,
#   2.973638140214549,
#   3.790812239702443],
#  'South of Market': [1.0295928201667404,
#   1.3591143955241507,
#   2.0866135155747005,
#   2.8631852618891522,
#   3.822135031970384],
#  'Excelsior': [0.9997947056206353,
#   1.2892458173375605,
#   1.8376155049513816,
#   3.3127221009517336,
#   3.878700367099147],
#  'Pacific Heights': [1.0159526702504906,
#   1.335929879305744,
#   1.9566873458705325,
#   2.7384252547550183,
#   3.7101681330384113],
#  'Tenderloin': [0.9698234505249138,
#   1.304515388879056,
#   1.8029987050246208,
#   2.7035654058036704,
#   3.2754345460837433],
#  'Bernal Heights': [0.9948108337514631,
#   1.3536742845386953,
#   2.0264115838878007,
#   3.4329052995711797,
#   4.595009963359098],
#  'Nob Hill': [0.988283963717278,
#   1.2187538793831498,
#   1.7699127908712526,
#   2.464727180027127,
#   3.369984518933145],
#  'Portola': [1.0022258208456098,
#   1.250613942054357,
#   1.804600633997217,
#   3.154746573778953,
#   3.6326454604259286],
#  'Western Addition': [1.1061895725457367,
#   1.3621064372614708,
#   2.2943106597592453,
#   3.3529010029480752,
#   4.696308787982003],
#  'Bayview': [0.9505941014717765,
#   1.1589424902814829,
#   1.7395346181850038,
#   3.2690273150020848,
#   3.3356675471461883],
#  'Potrero Hill': [1.0115169489424816,
#   1.3074099640183685,
#   2.0430725139457193,
#   2.9135914563291423,
#   4.089516616319786],
#  'Noe Valley': [1.057709012050848,
#   1.4295168562018938,
#   2.23473452950964,
#   3.2111263516744826,
#   4.667400811113605],
#  'Russian Hill': [1.0029364432844177,
#   1.3730737579631858,
#   1.9524662878273094,
#   2.707803789576694,
#   3.488949748693236],
#  'Inner Sunset': [1.0050554698431535,
#   1.3562720686412932,
#   1.8937947814596603,
#   2.957841429822533,
#   4.074635554227258],
#  'Crocker Amazon': [0.9833996694558123,
#   1.2154082757692235,
#   1.7491188981114727,
#   3.181110068361443,
#   3.478364397498987],
#  'Visitacion Valley': [0.9759100794423047,
#   1.2381322855027121,
#   1.851776133410793,
#   3.361250105027167,
#   3.354272306800521],
#  'Golden Gate Heights': [1.0223676714204286,
#   1.3253374521847556,
#   1.84873680277748,
#   2.8068375912759214,
#   3.536892909923641],
#  'Marina': [1.0017308322029044,
#   1.3173553657047294,
#   1.963918865167345,
#   2.9723630672609453,
#   4.442548606328031],
#  'Ingleside': [0.9769694041776673,
#   1.2364721331156812,
#   1.7714397594520943,
#   3.1845442040129956,
#   3.868667857715172],
#  'Mission Terrace': [1.020944628757193,
#   1.3184781128921328,
#   1.9547657460569752,
#   3.342471636119869,
#   4.394240273234843],
#  'Parkmerced': [0.985803454479818,
#   1.182055606004541,
#   1.3296817200698614,
#   1.4735422049256643,
#   1.5556318147450983],
#  'Silver Terrace': [0.9861164095160243,
#   1.2381771914111996,
#   1.809439044421806,
#   3.2277925270324146,
#   3.7695008474118246],
#  'Oceanview': [1.0057253559397452,
#   1.265847779458612,
#   1.8589539001285773,
#   3.5609181844978006,
#   3.824055602202964],
#  'North Beach': [1.0127204237403533,
#   1.2344107779623452,
#   1.7727275346577396,
#   2.5598481446408807,
#   3.274246410166147],
#  'Lone Mountain': [1.0806639379462366,
#   1.352253630164907,
#   2.0401859474792983,
#   3.1567357613319813,
#   4.92370234561127],
#  'Chinatown': [1.0757633329728558,
#   1.1940428874300126,
#   1.521786446359834,
#   2.1253372952195293,
#   2.3911465023146157],
#  'Sunnyside': [1.0127749537243949,
#   1.3175033138304544,
#   1.894105789412647,
#   3.040833560035363,
#   3.4908481176264696],
#  'Outer Mission': [0.9807249585927638,
#   1.2032166492410519,
#   1.7188775683991686,
#   3.190228760985197,
#   3.650551432453868],
#  'Panhandle': [1.128108389930492,
#   1.4649796207268624,
#   2.1175821292853345,
#   3.0578597081927317,
#   4.546193669032055],
#  'Buena Vista': [1.0131378970240776,
#   1.2949484918861678,
#   2.0835368351712082,
#   2.8761977263096807,
#   4.289734957253991],
#  'Ingleside Heights': [0.990391065106136,
#   1.276285323260158,
#   1.8732363333713535,
#   3.295451884424858,
#   3.850457331996641],
#  'Lower Pacific Heights': [1.0157240736799789,
#   1.317633317567883,
#   1.9806785661421953,
#   2.783807252621989,
#   4.029419006605455],
#  'South Beach': [0.9676421729432717,
#   1.2278262159471551,
#   1.8679177238512636,
#   2.8433580132331486,
#   4.213823718081007],
#  'Haight': [1.008637982894011,
#   1.3845667882735584,
#   1.94148854406853,
#   2.710588051559577,
#   4.187221341017663],
#  'Duboce Triangle': [1.0368623734125693,
#   1.2843311824985517,
#   2.056594675397542,
#   2.608648490354209,
#   3.843037722329431],
#  'Presidio Heights': [1.0126385634763442,
#   1.3207886361366596,
#   2.1884466769126925,
#   3.1537472354568896,
#   5.1788216619900345],
#  'Laurel Heights': [1.0428524295110555,
#   1.4024553694946391,
#   2.2077209345970004,
#   3.1404459999834122,
#   5.19895477964455],
#  'Hayes Valley': [1.1178769543842213,
#   1.4452717033471816,
#   2.3844730071839275,
#   3.300469024272923,
#   4.576146606703595],
#  'Upper Market': [0.9531526160533943,
#   1.2696779710661552,
#   1.9843380547986877,
#   2.9783483408227585,
#   4.046039381108466],
#  'Miraloma Park': [0.9504743627952612,
#   1.2786589418536256,
#   1.8976391957238563,
#   2.851383791256743,
#   3.818953784762959],
#  'Lakeshore': [0.9836153620005643,
#   1.2208745305332178,
#   1.6450054926237694,
#   2.514082023791556,
#   2.8268199745001508],
#  'Hunters Point': [0.8510444368134912,
#   1.1024932754373884,
#   1.5193633305103995,
#   2.9187458231265015,
#   3.87244382961818],
#  'Cow Hollow': [1.0414083782337253,
#   1.389973102740613,
#   2.139352251613957,
#   3.0625647326395775,
#   4.478473932964329],
#  'Glen Park': [0.98480866498233,
#   1.3386355358757531,
#   1.9317195065272283,
#   3.0281739672768633,
#   4.3157053366507006],
#  'Alamo Square': [1.1657728246294314,
#   1.3385431791203828,
#   2.0203381272497114,
#   2.972383817529981,
#   4.049802464987973],
#  'Telegraph Hill': [1.002491614596796,
#   1.2354952347648058,
#   1.7406763951616864,
#   2.470326083897877,
#   3.109127584749335],
#  'Financial District': [0.8395897427442026,
#   0.9636966460713502,
#   1.2761227290071933,
#   1.9149074418316867,
#   2.216925745314214],
#  'Lake': [1.0409085350680651,
#   1.3278754034933935,
#   2.1841098555518617,
#   3.0645618068747127,
#   4.388484071398997],
#  'Diamond Heights': [0.9811320259558464,
#   1.3297435914709477,
#   1.9706580726702547,
#   3.0830866832173096,
#   4.187490227737828],
#  'Stonestown': [0.9985419304057657,
#   1.27622572569512,
#   1.8091136907152459,
#   2.766012652233662,
#   3.34562084831178],
#  'Clarendon Heights': [0.9468828191191819,
#   1.2592520420132873,
#   1.883375300778039,
#   2.6129845841497077,
#   3.9314386281649263],
#  'Anza Vista': [1.0173301356038194,
#   1.261263913186418,
#   2.0219528112322056,
#   2.914843786106481,
#   4.06783251444071],
#  'Merced Manor': [0.9984076935388383,
#   1.2042459197529196,
#   1.6551956996855928,
#   2.4725683999807666,
#   3.2298827309254343],
#  'Westwood Park': [0.9761618478994256,
#   1.3597556874650123,
#   1.9892547984251632,
#   2.936956068947815,
#   3.5750502935348716],
#  'Sherwood Forest': [0.991310966077306,
#   1.3030148157686336,
#   1.8488330328832714,
#   2.63368139815051,
#   3.488634873920964],
#  'Ingleside Terrace': [1.0424155333553096,
#   1.3447799879044084,
#   1.9987141449365096,
#   2.736828712106689,
#   3.899021718115925],
#  'Forest Hill': [1.0929972344409769,
#   1.4420570685752365,
#   2.184520459013021,
#   3.245760417635637,
#   4.55805366771535],
#  'Corona Heights': [1.0515038045283986,
#   1.2998784596141537,
#   2.099895564088428,
#   2.9569787614046796,
#   4.4286779384933395],
#  'Midtown Terrace': [0.9290495961087344,
#   1.2612768975849895,
#   1.7552591353797324,
#   2.587344755716733,
#   3.4982191748383897],
#  'Little Hollywood': [0.9969618042606885,
#   1.1957439998803052,
#   1.6369341142992506,
#   2.891550459674854,
#   2.682891895502156],
#  'North Waterfront': [0.9736215457080754,
#   1.2417644137251622,
#   1.678670669679645,
#   2.1422522754211486,
#   2.6638764634506806],
#  'Forest Knolls': [1.0395272210222084,
#   1.2997263016919822,
#   1.80168440988251,
#   2.5183060945294233,
#   3.224742049752334],
#  'Seacliff': [1.0833271614057425,
#   1.4041117835916732,
#   2.033115373989537,
#   2.971192053320024,
#   4.852827448157345],
#  'St. Francis Wood': [1.0958291577955652,
#   1.3502189444028614,
#   1.8879029480765868,
#   2.6792673781441643,
#   3.675916572016545],
#  'Mount Davidson Manor': [0.9980808098745566,
#   1.3083317770210683,
#   1.8952373177889834,
#   2.7392543534324276,
#   3.484301982013427],
#  'Balboa Terrace': [1.06743855923629,
#   1.3955997580658077,
#   1.9725170278894093,
#   3.0025533156580266,
#   3.42551092159732],
#  'Monterey Heights': [1.0864530876864682,
#   1.4804866436306694,
#   1.9977865634471959,
#   2.9173884950772053,
#   3.8379666933598324],
#  'Westwood Highlands': [1.0290973927031062,
#   1.3928241575554057,
#   1.9970839733287766,
#   2.9161000108199344,
#   4.117525340658734]}

# %%
#outfile.close()

# %%
#outfile = open("medianPredict", 'wb')
outfile = open("Out", 'wb')

# %%
#pickle.dump(medianPred, outfile)
pickle.dump(districtOut, outfile)
outfile.close()
